# %% [markdown]
# <a href="https://colab.research.google.com/github/akikohaku/Machine_Vision/blob/main/imv_wk2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the matplotlib package

# %% [markdown]
# * Can be used to creating static, animated, and interactive visualisations in Python
# * plotting in a MATLAB style

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Plotting

# %%
x = [-2, -1, 0, 1, 2]
y = [10, 100, 200, 500, 1000]
plt.plot(x, y)
plt.show()

# %% [markdown]
# * Add labels

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# * Change colour/marker and specify axes

# %%
plt.plot(x, y, 'g--')
plt.xlabel('x')
plt.ylabel('y')
plt.axis([0, 2, 0, 800])
plt.show()

# %% [markdown]
# * Scatter plot

# %%
x = np.arange(10)
y = np.arange(10)
c = np.arange(10)
s = np.arange(1, 20, 2)

plt.scatter(x=x, y=y, c=c, s=s)
plt.show()

# %% [markdown]
# * Bar chart and subplots

# %%
cat = ['cat0', 'cat1']
num = [10, 20]
plt.figure(figsize=(10, 6))
plt.subplot(121)
plt.bar(cat, num)
plt.subplot(122)
plt.bar(cat, num, width=0.5)
plt.suptitle('example', fontsize=20)
plt.show()

# %%
def f(x,A):
  b=1.5
  c=0.3
  return A*np.cos(x)+np.sqrt(b*b-(A*np.sin(x)-c)**2)


x = np.linspace(0, 2*np.pi, 1000)
y=f(x,1)
plt.plot(x,y)

x = np.linspace(0, 2*np.pi, 1000)
y=f(x,0.5)

plt.plot(x,y,"r--")

plt.show()

# %% [markdown]
# # Read in an image

# %% [markdown]
# * using matplotlib

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/content/sample_img.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# * using OpenCV

# %%
import cv2
img = cv2.imread('/content/sample_img.png')
#cv2.imshow('image', img)  # this cannot be used in Colab

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1600>

# %% [markdown]
# * Try to fix this problem yourself

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb) # note that the colour is not displayed correctly, why?
# OpenCV uses BGR instead of RGB!
# How to fix it?

# %% [markdown]
# * using the Python Imaging Library (PIL)

# %%
from PIL import Image
from IPython.display import display # to display images
pil_im = Image.open('/content/sample_img.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x1600>

# %% [markdown]
# * cropping

# %%
img_cropped = img[0:100, 50:300, :]
plt.imshow(img_cropped)

# %% [markdown]
# * RGB to Grey (recall lecture 2)

# %%
img_grey = img[:, :, 0]*0.2989 + img[:, :, 1]*0.5870 + img[:, :, 2]*0.1140
img_grey = img_grey.astype(np.uint8)
plt.imshow(img_grey)

# %%
plt.imshow(img_grey, cmap='gray')  # using the gray colour space

# %%
height, width = img.shape[:2]
img_resize=cv2.resize(img_grey,[int(height/2),int(width/2)])
cv2_imshow(img_resize)
# Out:
# <PIL.Image.Image image mode=L size=800x800>

# %%
height, width = img.shape[:2]
print(height,width)
img_cropped = img[int(height/4):int(height/4*3), int(width/4):int(width/4*3), :]
cv2_imshow(img_cropped)
# Out:
# 1600 1600
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
fig = plt.figure(figsize=(10, 10))

rows=2
columns=2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) )
plt.axis('off')
plt.title("colour image")

fig.add_subplot(rows, columns, 2)
plt.imshow(img_grey, cmap='gray')
plt.axis('off')
plt.title("greyscale image")

fig.add_subplot(rows, columns, 3)
plt.imshow(img_resize, cmap='gray')
plt.axis('off')
plt.title("resized greyscale image")

fig.add_subplot(rows, columns, 4)
plt.imshow(cv2.cvtColor(img_cropped, cv2.COLOR_BGR2RGB) )
plt.axis('off')
plt.title("cropped colour image")

plt.savefig('/content/output.png')

# %% [markdown]
# # Explore other methods for image cropping and colour-greyscale conversion enabled by different python packages yourself
